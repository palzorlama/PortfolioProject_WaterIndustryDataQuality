# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load the main dataset from an Excel file with specific columns
def load_main_data(excel_path):
    """
    Load the main dataset from the Excel file. 
    Only 'time' and 'Level' columns are read.
    """
    try:
        main_df = pd.read_excel("LevelData.xlsx", usecols=['time', 'Level'])
        main_df['time'] = pd.to_datetime(main_df['time'])  # Ensure 'time' column is datetime
        return main_df
    except Exception as e:
        print(f"Error loading main data: {e}")
        return None

# Load the rainfall forecast data from an Excel file
def load_forecast_data(excel_path):
    """
    Load the forecast data from an Excel file. 
    The Excel file is expected to have 'date' and 'forecast_rainfall' columns.
    """
    try:
        forecast_df = pd.read_excel("ForecastAndHistoric.xlsx")
        forecast_df['date'] = pd.to_datetime(forecast_df['date'])  # Ensure 'date' column is datetime
        return forecast_df.set_index('date')['forecast_rainfall'].to_dict()  # Convert to a dictionary
    except Exception as e:
        print(f"Error loading forecast data: {e}")
        return None

# %%
# Path to the Excel files
main_data_path = 'LevelData.xlsx'  # Main dataset (Excel file path)
rainfall_forecast_path = 'ForecastAndHistoric.xlsx'  # Rainfall forecast data (Excel file path)

# Load the data
main_data = load_main_data(main_data_path)
forecast_rainfall = load_forecast_data(rainfall_forecast_path)

# Check only the first 5 rows of the data to avoid large output
if main_data is not None:
    print(main_data.head(5))  # Limiting output to 5 rows

if forecast_rainfall is not None:
    print({k: forecast_rainfall[k] for k in list(forecast_rainfall.keys())[:5]})  # Show only 5 entries
# Out:
#                  time   Level
# 0 2024-02-05 09:45:00 -2600.0
# 1 2024-02-05 10:00:00   250.0
# 2 2024-02-05 10:15:00 -2600.0
# 3 2024-02-05 10:30:00 -2600.0
# 4 2024-02-05 10:45:00 -2600.0
# {Timestamp('2023-03-01 00:00:00'): 0.0, Timestamp('2023-03-01 00:05:00'): 0.0, Timestamp('2023-03-01 00:10:00'): 0.0, Timestamp('2023-03-01 00:15:00'): 0.0, Timestamp('2023-03-01 00:20:00'): 0.0}

# %%
# Define a function to check if a value is negative
def is_negative(value):
    return value < 0

# %%
# Black-box function to estimate values using averaging of the previous and forward 2-4 readings
def black_box_estimation(index, main_data):
    """
    Estimate the value using a black-box function that averages
    the previous 2-4 readings and forward 2-4 readings.
    """
    num_rows = len(main_data)
    # Get the previous 2-4 readings (within bounds)
    previous_readings = main_data['Level'].iloc[max(0, index-4):index].values
    # Get the forward 2-4 readings (within bounds)
    forward_readings = main_data['Level'].iloc[index+1:min(num_rows, index+5)].values
    
    # Combine previous and forward readings to compute average
    all_readings = np.concatenate((previous_readings, forward_readings))
    if len(all_readings) > 0:
        estimated_value = np.mean(all_readings)
    else:
        estimated_value = 0  # Default to 0 if no readings are available
    
    # Ensure that the estimated value is non-negative
    estimated_value = max(estimated_value, 0)

    # Print out the correction details
    print(f"Black-box correction at index {index}: Corrected value = {estimated_value}")
    
    return estimated_value

# Create a copy of the main data to store the corrected values
corrected_data = main_data.copy()

# Iterate through the main data and fix negative values
installation_issue = False
negative_start_time = None
consecutive_negatives = 0

for i in range(len(main_data)):
    level_value = main_data.loc[i, 'Level']
    
    if is_negative(level_value):
        if negative_start_time is None:
            negative_start_time = i
        consecutive_negatives += 1
        
        # Estimate the value using the black-box function
        corrected_data.loc[i, 'Level'] = black_box_estimation(i, main_data)
    else:
        if consecutive_negatives > 0:
            if consecutive_negatives > 12:  # If more than 12 hours of negative values
                installation_issue = True
                print(f"Potential installation issue detected starting at index {negative_start_time}")
            consecutive_negatives = 0
            negative_start_time = None
# Out:
# Black-box correction at index 0: Corrected value = 0
# Black-box correction at index 2: Corrected value = 0
# Black-box correction at index 3: Corrected value = 0
# Black-box correction at index 4: Corrected value = 0
# Black-box correction at index 5: Corrected value = 0
# Black-box correction at index 6: Corrected value = 0
# Black-box correction at index 7: Corrected value = 0
# Black-box correction at index 8: Corrected value = 0
# Black-box correction at index 9: Corrected value = 0
# Black-box correction at index 10: Corrected value = 0
# Black-box correction at index 11: Corrected value = 0
# Black-box correction at index 12: Corrected value = 0
# Black-box correction at index 93: Corrected value = 4.875
# Black-box correction at index 94: Corrected value = 5.0
# Black-box correction at index 95: Corrected value = 3.875
# Black-box correction at index 106: Corrected value = 4.75
# Black-box correction at index 231: Corrected value = 8.0
# Black-box correction at index 232: Corrected value = 8.0
# Black-box correction at index 242: Corrected value = 8.375
# Black-box correction at index 286: Corrected value = 9.25
# Black-box correction at index 317: Corrected value = 6.25
# Black-box correction at index 321: Corrected value = 3.375
# Black-box correction at index 322: Corrected value = 7.5
# Black-box correction at index 407: Corrected value = 2.0
# Black-box correction at index 415: Corrected value = 0
# Black-box correction at index 416: Corrected value = 1.375
# Black-box correction at index 417: Corrected value = 0
# Black-box correction at index 418: Corrected value = 0
# Black-box correction at index 421: Corrected value = 1.75
# Black-box correction at index 424: Corrected value = 2.25
# Black-box correction at index 426: Corrected value = 3.25
# Black-box correction at index 499: Corrected value = 8.125
# Black-box correction at index 523: Corrected value = 9.125
# Black-box correction at index 529: Corrected value = 7.5
# Black-box correction at index 703: Corrected value = 8.0
# Black-box correction at index 713: Corrected value = 8.875
# Black-box correction at index 877: Corrected value = 12.875
# Black-box correction at index 900: Corrected value = 10.875
# Black-box correction at index 999: Corrected value = 9.0
# Black-box correction at index 1106: Corrected value = 9.125
# Black-box correction at index 1215: Corrected value = 6.25
# Black-box correction at index 1246: Corrected value = 10.875
# Black-box correction at index 1286: Corrected value = 4.5
# Black-box correction at index 1341: Corrected value = 10.625
# Black-box correction at index 1381: Corrected value = 10.125
# Black-box correction at index 1486: Corrected value = 6.875
# Black-box correction at index 1527: Corrected value = 9.875
# Black-box correction at index 1575: Corrected value = 6.875
# Black-box correction at index 1581: Corrected value = 7.125
# Black-box correction at index 1643: Corrected value = 10.5
# Black-box correction at index 1659: Corrected value = 11.25
# Black-box correction at index 1667: Corrected value = 12.125
# Black-box correction at index 1680: Corrected value = 7.25
# Black-box correction at index 1681: Corrected value = 8.5
# Black-box correction at index 1759: Corrected value = 9.25
# Black-box correction at index 1821: Corrected value = 3.5
# Black-box correction at index 1823: Corrected value = 5.875
# Black-box correction at index 1866: Corrected value = 0.75
# Black-box correction at index 1867: Corrected value = 2.0
# Black-box correction at index 1870: Corrected value = 5.0
# Black-box correction at index 2160: Corrected value = 11.125
# Black-box correction at index 2214: Corrected value = 11.5
# Black-box correction at index 2239: Corrected value = 10.875
# Black-box correction at index 2258: Corrected value = 7.625
# Black-box correction at index 2261: Corrected value = 6.0
# Black-box correction at index 2311: Corrected value = 9.375
# Black-box correction at index 2348: Corrected value = 5.0
# Black-box correction at index 2497: Corrected value = 8.125
# Black-box correction at index 2540: Corrected value = 3.125
# Black-box correction at index 2555: Corrected value = 1.75
# Black-box correction at index 2563: Corrected value = 3.625
# Black-box correction at index 2713: Corrected value = 8.75
# Black-box correction at index 2718: Corrected value = 7.625
# Black-box correction at index 2738: Corrected value = 5.75
# Black-box correction at index 2739: Corrected value = 5.25
# Black-box correction at index 2811: Corrected value = 7.375
# Black-box correction at index 2857: Corrected value = 2.875
# Black-box correction at index 3006: Corrected value = 6.75
# Black-box correction at index 3131: Corrected value = 0
# Black-box correction at index 3132: Corrected value = 0
# Black-box correction at index 3133: Corrected value = 0
# Black-box correction at index 3134: Corrected value = 0
# Black-box correction at index 3135: Corrected value = 0
# Black-box correction at index 3136: Corrected value = 0
# Black-box correction at index 3212: Corrected value = 10.125
# Black-box correction at index 3217: Corrected value = 9.25
# Black-box correction at index 3353: Corrected value = 7.875
# Black-box correction at index 3468: Corrected value = 8.625
# Black-box correction at index 3473: Corrected value = 8.5
# Black-box correction at index 3518: Corrected value = 2.625
# Black-box correction at index 3582: Corrected value = 9.5
# Black-box correction at index 3634: Corrected value = 7.75
# Black-box correction at index 3810: Corrected value = 5.625
# Black-box correction at index 3811: Corrected value = 7.375
# Black-box correction at index 3812: Corrected value = 9.125
# Black-box correction at index 3820: Corrected value = 11.875
# Black-box correction at index 3827: Corrected value = 9.375
# Black-box correction at index 3886: Corrected value = 4.375
# Black-box correction at index 3925: Corrected value = 6.375
# Black-box correction at index 3939: Corrected value = 4.75
# Black-box correction at index 3941: Corrected value = 6.0
# Black-box correction at index 3948: Corrected value = 9.625
# Black-box correction at index 4049: Corrected value = 5.375
# Black-box correction at index 4107: Corrected value = 1.375
# Black-box correction at index 4308: Corrected value = 9.25
# Black-box correction at index 4359: Corrected value = 10.125
# Black-box correction at index 4554: Corrected value = 10.25
# Black-box correction at index 4632: Corrected value = 8.375
# Black-box correction at index 4795: Corrected value = 6.875
# Black-box correction at index 4847: Corrected value = 10.125
# Black-box correction at index 5001: Corrected value = 10.875
# Black-box correction at index 5021: Corrected value = 2.0
# Black-box correction at index 5023: Corrected value = 2.5
# Black-box correction at index 5024: Corrected value = 2.875
# Black-box correction at index 5025: Corrected value = 4.5
# Black-box correction at index 5036: Corrected value = 9.125
# Black-box correction at index 5049: Corrected value = 2.75
# Black-box correction at index 5135: Corrected value = 10.25
# Black-box correction at index 5272: Corrected value = 7.875
# Black-box correction at index 5506: Corrected value = 7.0
# Black-box correction at index 5515: Corrected value = 4.0
# Black-box correction at index 5516: Corrected value = 1.75
# Black-box correction at index 5530: Corrected value = 1.875
# Black-box correction at index 5534: Corrected value = 2.125
# Black-box correction at index 5616: Corrected value = 9.125
# Black-box correction at index 5619: Corrected value = 8.125
# Black-box correction at index 5645: Corrected value = 6.25
# Black-box correction at index 5679: Corrected value = 9.75
# Black-box correction at index 5709: Corrected value = 5.875
# Black-box correction at index 5743: Corrected value = 2.0
# Black-box correction at index 5746: Corrected value = 1.0
# Black-box correction at index 5751: Corrected value = 1.75
# Black-box correction at index 5756: Corrected value = 1.875
# Black-box correction at index 5795: Corrected value = 12.375
# Black-box correction at index 5899: Corrected value = 9.75
# Black-box correction at index 5905: Corrected value = 7.625
# Black-box correction at index 5956: Corrected value = 8.375
# Black-box correction at index 5960: Corrected value = 8.375
# Black-box correction at index 6135: Corrected value = 9.375
# Black-box correction at index 6165: Corrected value = 8.375
# Black-box correction at index 6309: Corrected value = 0
# Black-box correction at index 6310: Corrected value = 0
# Black-box correction at index 6311: Corrected value = 0
# Black-box correction at index 6312: Corrected value = 0
# Black-box correction at index 6313: Corrected value = 0
# Black-box correction at index 6331: Corrected value = 9.75
# Black-box correction at index 6360: Corrected value = 7.0
# Black-box correction at index 6366: Corrected value = 8.5
# Black-box correction at index 6535: Corrected value = 7.25
# Black-box correction at index 6707: Corrected value = 7.25
# Black-box correction at index 6718: Corrected value = 11.0
# Black-box correction at index 6755: Corrected value = 10.125
# Black-box correction at index 6833: Corrected value = 7.875
# Black-box correction at index 6840: Corrected value = 14.25
# Black-box correction at index 6849: Corrected value = 9.375
# Black-box correction at index 6852: Corrected value = 8.5
# Black-box correction at index 6860: Corrected value = 7.0
# Black-box correction at index 6949: Corrected value = 8.25
# Black-box correction at index 7032: Corrected value = 6.75
# Black-box correction at index 7124: Corrected value = 11.0
# Black-box correction at index 7133: Corrected value = 8.75
# Black-box correction at index 7195: Corrected value = 10.25
# Black-box correction at index 7213: Corrected value = 7.625
# Black-box correction at index 7247: Corrected value = 9.25
# Black-box correction at index 7338: Corrected value = 9.75
# Black-box correction at index 7391: Corrected value = 9.375
# Black-box correction at index 7472: Corrected value = 5.625
# Black-box correction at index 7482: Corrected value = 5.75
# Black-box correction at index 7581: Corrected value = 9.25
# Black-box correction at index 7604: Corrected value = 7.25
# Black-box correction at index 7631: Corrected value = 5.875
# Black-box correction at index 7666: Corrected value = 9.75
# Black-box correction at index 7705: Corrected value = 7.25
# Black-box correction at index 7762: Corrected value = 8.875
# Black-box correction at index 7809: Corrected value = 4.5
# Black-box correction at index 7811: Corrected value = 3.0
# Black-box correction at index 7910: Corrected value = 9.125
# Black-box correction at index 7920: Corrected value = 7.125
# Black-box correction at index 7940: Corrected value = 8.25
# Black-box correction at index 7955: Corrected value = 8.0
# Black-box correction at index 7960: Corrected value = 5.875
# Black-box correction at index 7978: Corrected value = 9.375
# Black-box correction at index 7980: Corrected value = 8.375
# Black-box correction at index 7997: Corrected value = 9.25
# Black-box correction at index 8013: Corrected value = 3.125
# Black-box correction at index 8018: Corrected value = 1.0
# Black-box correction at index 8023: Corrected value = 3.125
# Black-box correction at index 8025: Corrected value = 3.5
# Black-box correction at index 8037: Corrected value = 4.0
# Black-box correction at index 8061: Corrected value = 8.5
# Black-box correction at index 8067: Corrected value = 7.25
# Black-box correction at index 8069: Corrected value = 3.5
# Black-box correction at index 8079: Corrected value = 7.875
# Black-box correction at index 8107: Corrected value = 11.25
# Black-box correction at index 8172: Corrected value = 7.625
# Black-box correction at index 8197: Corrected value = 8.75
# Black-box correction at index 8245: Corrected value = 8.0
# Black-box correction at index 8248: Corrected value = 9.75
# Black-box correction at index 8280: Corrected value = 10.625
# Black-box correction at index 8288: Corrected value = 10.75
# Black-box correction at index 8350: Corrected value = 4.75
# Black-box correction at index 8376: Corrected value = 6.5
# Black-box correction at index 8377: Corrected value = 5.75
# Black-box correction at index 8456: Corrected value = 6.375
# Black-box correction at index 8464: Corrected value = 2.75
# Black-box correction at index 8466: Corrected value = 3.0
# Black-box correction at index 8468: Corrected value = 2.625
# Black-box correction at index 8531: Corrected value = 6.125
# Black-box correction at index 8589: Corrected value = 8.0
# Black-box correction at index 8595: Corrected value = 10.25
# Black-box correction at index 8674: Corrected value = 10.5
# Black-box correction at index 8689: Corrected value = 9.625
# Black-box correction at index 8700: Corrected value = 9.375
# Black-box correction at index 8701: Corrected value = 6.125
# Black-box correction at index 8726: Corrected value = 8.875
# Black-box correction at index 8738: Corrected value = 5.125
# Black-box correction at index 8745: Corrected value = 6.625
# Black-box correction at index 8781: Corrected value = 3.125
# Black-box correction at index 8785: Corrected value = 2.25
# Black-box correction at index 8786: Corrected value = 2.625
# Black-box correction at index 8787: Corrected value = 1.125
# Black-box correction at index 8798: Corrected value = 1.5
# Black-box correction at index 8816: Corrected value = 4.5
# Black-box correction at index 8823: Corrected value = 3.0
# Black-box correction at index 8826: Corrected value = 4.125
# Black-box correction at index 8923: Corrected value = 6.75
# Black-box correction at index 8946: Corrected value = 8.875
# Black-box correction at index 8947: Corrected value = 7.875
# Black-box correction at index 8951: Corrected value = 7.375
# Black-box correction at index 8956: Corrected value = 4.5
# Black-box correction at index 8971: Corrected value = 5.0
# Black-box correction at index 8973: Corrected value = 6.375
# Black-box correction at index 9028: Corrected value = 9.25
# Black-box correction at index 9071: Corrected value = 7.125
# Black-box correction at index 9074: Corrected value = 6.625
# Black-box correction at index 9119: Corrected value = 6.25
# Black-box correction at index 9222: Corrected value = 7.0
# Black-box correction at index 9258: Corrected value = 6.125
# Black-box correction at index 9265: Corrected value = 4.0
# Black-box correction at index 9306: Corrected value = 8.75
# Black-box correction at index 9310: Corrected value = 4.375
# Black-box correction at index 9311: Corrected value = 8.125
# Black-box correction at index 9359: Corrected value = 5.0
# Black-box correction at index 9382: Corrected value = 3.25
# Black-box correction at index 9392: Corrected value = 9.625
# Black-box correction at index 9427: Corrected value = 3.625
# Black-box correction at index 9441: Corrected value = 9.25
# Black-box correction at index 9451: Corrected value = 7.0
# Black-box correction at index 9455: Corrected value = 6.125
# Black-box correction at index 9549: Corrected value = 8.375
# Black-box correction at index 9586: Corrected value = 10.375
# Black-box correction at index 9629: Corrected value = 4.875
# Black-box correction at index 9650: Corrected value = 4.625
# Black-box correction at index 9783: Corrected value = 8.375
# Black-box correction at index 9813: Corrected value = 3.5
# Black-box correction at index 9815: Corrected value = 3.875
# Black-box correction at index 9852: Corrected value = 2.75
# Black-box correction at index 9853: Corrected value = 3.5
# Black-box correction at index 9855: Corrected value = 2.25
# Black-box correction at index 9860: Corrected value = 2.0
# Black-box correction at index 9862: Corrected value = 0.875
# Black-box correction at index 9863: Corrected value = 0.5
# Black-box correction at index 9864: Corrected value = 0.375
# Black-box correction at index 9867: Corrected value = 0.75
# Black-box correction at index 9868: Corrected value = 3.0
# Black-box correction at index 9869: Corrected value = 3.5
# Black-box correction at index 9871: Corrected value = 4.875
# Black-box correction at index 9905: Corrected value = 0.5
# Black-box correction at index 9906: Corrected value = 0
# Black-box correction at index 9907: Corrected value = 0.75
# Black-box correction at index 9908: Corrected value = 0.875
# Black-box correction at index 9909: Corrected value = 2.375
# Black-box correction at index 9910: Corrected value = 4.25
# Black-box correction at index 9924: Corrected value = 10.0
# Black-box correction at index 9934: Corrected value = 0.625
# Black-box correction at index 9938: Corrected value = 1.0
# Black-box correction at index 9939: Corrected value = 0
# Black-box correction at index 9944: Corrected value = 3.5
# Black-box correction at index 9949: Corrected value = 2.25
# Black-box correction at index 9951: Corrected value = 0.25
# Black-box correction at index 9954: Corrected value = 0
# Black-box correction at index 9955: Corrected value = 1.25
# Black-box correction at index 9956: Corrected value = 1.625
# Black-box correction at index 9957: Corrected value = 1.625
# Black-box correction at index 9968: Corrected value = 5.875
# Black-box correction at index 9976: Corrected value = 7.875
# Black-box correction at index 9990: Corrected value = 4.875
# Black-box correction at index 9991: Corrected value = 2.875
# Black-box correction at index 9992: Corrected value = 1.875
# Black-box correction at index 9995: Corrected value = 2.0
# Black-box correction at index 9996: Corrected value = 3.5
# Black-box correction at index 9997: Corrected value = 4.5
# Black-box correction at index 9999: Corrected value = 5.5
# Black-box correction at index 10020: Corrected value = 6.75
# Black-box correction at index 10027: Corrected value = 8.5
# Black-box correction at index 10035: Corrected value = 7.125
# Black-box correction at index 10037: Corrected value = 4.0
# Black-box correction at index 10040: Corrected value = 1.25
# Black-box correction at index 10041: Corrected value = 0.375
# Black-box correction at index 10042: Corrected value = 0.375
# Black-box correction at index 10043: Corrected value = 0
# Black-box correction at index 10044: Corrected value = 0
# Black-box correction at index 10046: Corrected value = 0
# Black-box correction at index 10049: Corrected value = 2.25
# Black-box correction at index 10050: Corrected value = 2.5
# Black-box correction at index 10051: Corrected value = 3.875
# Black-box correction at index 10061: Corrected value = 5.625
# Black-box correction at index 10062: Corrected value = 5.625
# Black-box correction at index 10064: Corrected value = 3.5
# Black-box correction at index 10072: Corrected value = 7.375
# Black-box correction at index 10076: Corrected value = 7.875
# Black-box correction at index 10079: Corrected value = 7.875
# Black-box correction at index 10084: Corrected value = 4.875
# Black-box correction at index 10085: Corrected value = 5.75
# Black-box correction at index 10087: Corrected value = 8.25
# Black-box correction at index 10105: Corrected value = 7.5
# Black-box correction at index 10128: Corrected value = 4.125
# Black-box correction at index 10131: Corrected value = 0.625
# Black-box correction at index 10132: Corrected value = 0.0
# Black-box correction at index 10136: Corrected value = 0.375
# Black-box correction at index 10137: Corrected value = 0.875
# Black-box correction at index 10138: Corrected value = 0
# Black-box correction at index 10139: Corrected value = 0
# Black-box correction at index 10140: Corrected value = 0
# Black-box correction at index 10142: Corrected value = 0
# Black-box correction at index 10144: Corrected value = 0
# Black-box correction at index 10146: Corrected value = 0
# Black-box correction at index 10147: Corrected value = 0
# Black-box correction at index 10150: Corrected value = 1.75
# Black-box correction at index 10151: Corrected value = 2.625
# Black-box correction at index 10157: Corrected value = 4.5
# Black-box correction at index 10158: Corrected value = 4.25
# Black-box correction at index 10163: Corrected value = 8.125
# Black-box correction at index 10169: Corrected value = 10.375
# Black-box correction at index 10176: Corrected value = 4.375
# Black-box correction at index 10179: Corrected value = 5.375
# Black-box correction at index 10180: Corrected value = 6.625
# Black-box correction at index 10212: Corrected value = 5.0
# Black-box correction at index 10222: Corrected value = 4.125
# Black-box correction at index 10261: Corrected value = 6.25
# Black-box correction at index 10263: Corrected value = 3.875
# Black-box correction at index 10291: Corrected value = 4.125
# Black-box correction at index 10294: Corrected value = 4.0
# Black-box correction at index 10300: Corrected value = 3.25
# Black-box correction at index 10302: Corrected value = 3.25
# Black-box correction at index 10305: Corrected value = 2.75
# Black-box correction at index 10309: Corrected value = 2.125
# Black-box correction at index 10310: Corrected value = 3.25
# Black-box correction at index 10318: Corrected value = 5.5
# Black-box correction at index 10358: Corrected value = 10.75
# Black-box correction at index 10371: Corrected value = 9.0
# Black-box correction at index 10380: Corrected value = 9.125
# Black-box correction at index 10386: Corrected value = 7.75
# Black-box correction at index 10393: Corrected value = 10.5
# Black-box correction at index 10411: Corrected value = 12.125
# Black-box correction at index 10478: Corrected value = 9.75
# Black-box correction at index 10496: Corrected value = 11.875
# Black-box correction at index 10511: Corrected value = 8.0
# Black-box correction at index 10522: Corrected value = 0.0
# Black-box correction at index 10523: Corrected value = 0
# Black-box correction at index 10524: Corrected value = 0
# Black-box correction at index 10527: Corrected value = 0.875
# Black-box correction at index 10528: Corrected value = 1.25
# Black-box correction at index 10529: Corrected value = 1.375
# Black-box correction at index 10533: Corrected value = 1.0
# Black-box correction at index 10534: Corrected value = 1.875
# Black-box correction at index 10535: Corrected value = 2.125
# Black-box correction at index 10536: Corrected value = 2.125
# Black-box correction at index 10542: Corrected value = 7.25
# Black-box correction at index 10543: Corrected value = 7.5
# Black-box correction at index 10568: Corrected value = 7.25
# Black-box correction at index 10596: Corrected value = 4.25
# Black-box correction at index 10600: Corrected value = 3.75
# Black-box correction at index 10605: Corrected value = 5.125
# Black-box correction at index 10608: Corrected value = 3.375
# Black-box correction at index 10616: Corrected value = 1.625
# Black-box correction at index 10688: Corrected value = 8.875
# Black-box correction at index 10691: Corrected value = 8.375
# Black-box correction at index 10737: Corrected value = 6.5
# Black-box correction at index 10746: Corrected value = 6.375
# Black-box correction at index 10796: Corrected value = 6.5
# Black-box correction at index 10797: Corrected value = 8.125
# Black-box correction at index 10853: Corrected value = 6.625
# Black-box correction at index 10928: Corrected value = 10.875
# Black-box correction at index 10962: Corrected value = 7.625
# Black-box correction at index 11153: Corrected value = 7.625
# Black-box correction at index 11248: Corrected value = 8.75
# Black-box correction at index 11272: Corrected value = 9.25
# Black-box correction at index 11293: Corrected value = 3.375
# Black-box correction at index 11327: Corrected value = 8.75
# Black-box correction at index 11387: Corrected value = 2.875
# Black-box correction at index 11394: Corrected value = 1.5
# Black-box correction at index 11395: Corrected value = 1.25
# Black-box correction at index 11396: Corrected value = 1.25
# Black-box correction at index 11397: Corrected value = 0
# Black-box correction at index 11399: Corrected value = 2.0
# Black-box correction at index 11401: Corrected value = 3.25
# Black-box correction at index 11417: Corrected value = 7.25
# Black-box correction at index 11439: Corrected value = 3.5
# Black-box correction at index 11460: Corrected value = 7.75
# Black-box correction at index 11473: Corrected value = 3.75
# Black-box correction at index 11484: Corrected value = 1.5
# Black-box correction at index 11485: Corrected value = 1.375
# Black-box correction at index 11490: Corrected value = 0.625
# Black-box correction at index 11491: Corrected value = 0.625
# Black-box correction at index 11492: Corrected value = 0.0
# Black-box correction at index 11493: Corrected value = 0
# Black-box correction at index 11494: Corrected value = 0.75
# Black-box correction at index 11496: Corrected value = 1.875
# Black-box correction at index 11499: Corrected value = 3.375
# Black-box correction at index 11519: Corrected value = 3.25
# Black-box correction at index 11522: Corrected value = 3.75
# Black-box correction at index 11524: Corrected value = 5.25
# Black-box correction at index 11525: Corrected value = 5.625
# Black-box correction at index 11532: Corrected value = 7.0
# Black-box correction at index 11538: Corrected value = 6.375
# Black-box correction at index 11574: Corrected value = 4.375
# Black-box correction at index 11575: Corrected value = 3.125
# Black-box correction at index 11578: Corrected value = 0.625
# Black-box correction at index 11579: Corrected value = 0.75
# Black-box correction at index 11580: Corrected value = 0.75
# Black-box correction at index 11581: Corrected value = 0
# Black-box correction at index 11582: Corrected value = 0
# Black-box correction at index 11583: Corrected value = 0
# Black-box correction at index 11586: Corrected value = 0
# Black-box correction at index 11589: Corrected value = 0
# Black-box correction at index 11592: Corrected value = 2.25
# Black-box correction at index 11593: Corrected value = 2.125
# Black-box correction at index 11597: Corrected value = 6.375
# Black-box correction at index 11601: Corrected value = 6.875
# Black-box correction at index 11622: Corrected value = 7.0
# Black-box correction at index 11634: Corrected value = 4.375
# Black-box correction at index 11655: Corrected value = 3.75
# Black-box correction at index 11656: Corrected value = 4.75
# Black-box correction at index 11664: Corrected value = 5.125
# Black-box correction at index 11670: Corrected value = 2.0
# Black-box correction at index 11671: Corrected value = 0
# Black-box correction at index 11674: Corrected value = 0
# Black-box correction at index 11675: Corrected value = 0
# Black-box correction at index 11676: Corrected value = 0
# Black-box correction at index 11677: Corrected value = 0
# Black-box correction at index 11678: Corrected value = 0
# Black-box correction at index 11679: Corrected value = 0
# Black-box correction at index 11680: Corrected value = 0
# Black-box correction at index 11683: Corrected value = 1.625
# Black-box correction at index 11686: Corrected value = 7.375
# Black-box correction at index 11693: Corrected value = 5.25
# Black-box correction at index 11705: Corrected value = 8.875
# Black-box correction at index 11760: Corrected value = 3.375
# Black-box correction at index 11762: Corrected value = 0.375
# Black-box correction at index 11764: Corrected value = 0
# Black-box correction at index 11771: Corrected value = 2.125
# Black-box correction at index 11775: Corrected value = 0
# Black-box correction at index 11777: Corrected value = 0.0
# Black-box correction at index 11784: Corrected value = 1.875
# Black-box correction at index 11785: Corrected value = 2.5
# Black-box correction at index 11795: Corrected value = 7.75
# Black-box correction at index 11810: Corrected value = 4.125
# Black-box correction at index 11821: Corrected value = 8.0
# Black-box correction at index 11856: Corrected value = 5.375
# Black-box correction at index 11859: Corrected value = 3.0
# Black-box correction at index 11863: Corrected value = 3.75
# Black-box correction at index 11864: Corrected value = 4.0
# Black-box correction at index 11868: Corrected value = 1.5
# Black-box correction at index 11870: Corrected value = 0
# Black-box correction at index 11871: Corrected value = 0.625
# Black-box correction at index 11874: Corrected value = 2.125
# Black-box correction at index 11876: Corrected value = 2.25
# Black-box correction at index 11879: Corrected value = 3.875
# Black-box correction at index 11881: Corrected value = 4.25
# Black-box correction at index 11882: Corrected value = 4.125
# Black-box correction at index 11886: Corrected value = 2.875
# Black-box correction at index 11887: Corrected value = 4.0
# Black-box correction at index 11889: Corrected value = 6.0
# Black-box correction at index 11906: Corrected value = 5.25
# Black-box correction at index 11907: Corrected value = 5.0
# Black-box correction at index 11911: Corrected value = 3.625
# Black-box correction at index 11919: Corrected value = 9.875
# Black-box correction at index 11948: Corrected value = 3.5
# Black-box correction at index 11949: Corrected value = 3.5
# Black-box correction at index 11959: Corrected value = 5.25
# Black-box correction at index 11960: Corrected value = 4.625
# Black-box correction at index 11964: Corrected value = 5.25
# Black-box correction at index 11976: Corrected value = 2.0
# Black-box correction at index 12045: Corrected value = 2.125
# Black-box correction at index 12046: Corrected value = 3.5
# Black-box correction at index 12047: Corrected value = 3.875
# Black-box correction at index 12057: Corrected value = 2.25
# Black-box correction at index 12059: Corrected value = 0.25
# Black-box correction at index 12060: Corrected value = 1.0
# Black-box correction at index 12062: Corrected value = 2.75
# Black-box correction at index 12076: Corrected value = 3.25
# Black-box correction at index 12079: Corrected value = 4.25
# Black-box correction at index 12108: Corrected value = 4.375
# Black-box correction at index 12109: Corrected value = 4.0
# Black-box correction at index 12110: Corrected value = 3.375
# Black-box correction at index 12113: Corrected value = 2.375
# Black-box correction at index 12144: Corrected value = 3.0
# Black-box correction at index 12148: Corrected value = 2.25
# Black-box correction at index 12155: Corrected value = 1.375
# Black-box correction at index 12161: Corrected value = 0.375
# Black-box correction at index 12197: Corrected value = 9.0
# Black-box correction at index 12206: Corrected value = 7.375
# Black-box correction at index 12281: Corrected value = 3.625
# Black-box correction at index 12284: Corrected value = 2.875
# Black-box correction at index 12288: Corrected value = 4.75
# Black-box correction at index 12294: Corrected value = 6.625
# Black-box correction at index 12321: Corrected value = 7.5
# Black-box correction at index 12360: Corrected value = 3.875
# Black-box correction at index 12392: Corrected value = 6.0
# Black-box correction at index 12418: Corrected value = 4.625
# Black-box correction at index 12531: Corrected value = 0.0
# Black-box correction at index 12532: Corrected value = 0
# Black-box correction at index 12533: Corrected value = 0
# Black-box correction at index 12534: Corrected value = 0
# Black-box correction at index 12535: Corrected value = 0
# Black-box correction at index 12536: Corrected value = 0
# Black-box correction at index 12537: Corrected value = 0
# Black-box correction at index 12538: Corrected value = 0
# Black-box correction at index 12585: Corrected value = 6.125
# Black-box correction at index 12663: Corrected value = 11.375
# Black-box correction at index 12706: Corrected value = 8.375
# Black-box correction at index 12725: Corrected value = 0.625
# Black-box correction at index 12726: Corrected value = 0.0
# Black-box correction at index 12727: Corrected value = 0.0
# Black-box correction at index 12729: Corrected value = 0
# Black-box correction at index 12734: Corrected value = 0.125
# Black-box correction at index 12736: Corrected value = 0
# Black-box correction at index 12738: Corrected value = 0
# Black-box correction at index 12740: Corrected value = 0
# Black-box correction at index 12741: Corrected value = 0
# Black-box correction at index 12744: Corrected value = 1.875
# Black-box correction at index 12745: Corrected value = 3.75
# Black-box correction at index 12748: Corrected value = 5.5
# Black-box correction at index 12775: Corrected value = 5.625
# Black-box correction at index 12784: Corrected value = 4.75
# Black-box correction at index 12785: Corrected value = 5.25
# Black-box correction at index 12787: Corrected value = 5.125
# Black-box correction at index 12822: Corrected value = 2.5
# Black-box correction at index 12844: Corrected value = 5.125
# Black-box correction at index 12850: Corrected value = 8.5
# Black-box correction at index 12875: Corrected value = 9.5
# Black-box correction at index 12881: Corrected value = 6.75
# Black-box correction at index 12883: Corrected value = 6.5
# Black-box correction at index 12959: Corrected value = 4.375
# Black-box correction at index 12966: Corrected value = 6.125
# Black-box correction at index 12975: Corrected value = 4.0
# Black-box correction at index 13011: Corrected value = 2.0
# Black-box correction at index 13046: Corrected value = 5.375
# Black-box correction at index 13049: Corrected value = 5.0
# Black-box correction at index 13050: Corrected value = 3.625
# Black-box correction at index 13109: Corrected value = 1.5
# Black-box correction at index 13114: Corrected value = 0.875
# Black-box correction at index 13140: Corrected value = 8.25
# Black-box correction at index 13150: Corrected value = 4.75
# Black-box correction at index 13188: Corrected value = 6.0
# Black-box correction at index 13191: Corrected value = 3.0
# Black-box correction at index 13193: Corrected value = 1.375
# Black-box correction at index 13195: Corrected value = 2.625
# Black-box correction at index 13206: Corrected value = 3.5
# Black-box correction at index 13207: Corrected value = 2.5
# Black-box correction at index 13214: Corrected value = 2.125
# Black-box correction at index 13217: Corrected value = 0.375
# Black-box correction at index 13222: Corrected value = 0.25
# Black-box correction at index 13224: Corrected value = 2.875
# Black-box correction at index 13230: Corrected value = 4.125
# Black-box correction at index 13236: Corrected value = 6.0
# Black-box correction at index 13238: Corrected value = 7.125
# Black-box correction at index 13282: Corrected value = 9.75
# Black-box correction at index 13329: Corrected value = 9.375
# Black-box correction at index 13335: Corrected value = 8.0
# Black-box correction at index 13375: Corrected value = 6.5
# Black-box correction at index 13391: Corrected value = 10.0
# Black-box correction at index 13408: Corrected value = 0.25
# Black-box correction at index 13412: Corrected value = 0.375
# Black-box correction at index 13442: Corrected value = 3.375
# Black-box correction at index 13446: Corrected value = 5.125
# Black-box correction at index 13456: Corrected value = 7.5
# Black-box correction at index 13457: Corrected value = 7.25
# Black-box correction at index 13485: Corrected value = 7.25
# Black-box correction at index 13490: Corrected value = 4.875
# Black-box correction at index 13491: Corrected value = 2.5
# Black-box correction at index 13494: Corrected value = 0.875
# Black-box correction at index 13499: Corrected value = 0.125
# Black-box correction at index 13539: Corrected value = 2.375
# Black-box correction at index 13540: Corrected value = 3.5
# Black-box correction at index 13541: Corrected value = 3.0
# Black-box correction at index 13580: Corrected value = 4.5
# Black-box correction at index 13590: Corrected value = 2.375
# Black-box correction at index 13591: Corrected value = 2.125
# Black-box correction at index 13592: Corrected value = 1.125
# Black-box correction at index 13593: Corrected value = 0
# Black-box correction at index 13594: Corrected value = 0
# Black-box correction at index 13596: Corrected value = 0
# Black-box correction at index 13597: Corrected value = 0
# Black-box correction at index 13598: Corrected value = 0
# Black-box correction at index 13599: Corrected value = 0
# Black-box correction at index 13601: Corrected value = 0.0
# Black-box correction at index 13607: Corrected value = 1.875
# Black-box correction at index 13608: Corrected value = 3.75
# Black-box correction at index 13611: Corrected value = 2.875
# Black-box correction at index 13614: Corrected value = 7.25
# Black-box correction at index 13624: Corrected value = 5.875
# Black-box correction at index 13635: Corrected value = 5.125
# Black-box correction at index 13638: Corrected value = 6.125
# Black-box correction at index 13639: Corrected value = 6.125
# Black-box correction at index 13682: Corrected value = 1.875
# Black-box correction at index 13689: Corrected value = 0.5
# Black-box correction at index 13690: Corrected value = 0.375
# Black-box correction at index 13692: Corrected value = 0
# Black-box correction at index 13694: Corrected value = 0
# Black-box correction at index 13695: Corrected value = 0
# Black-box correction at index 13696: Corrected value = 0
# Black-box correction at index 13697: Corrected value = 0
# Black-box correction at index 13698: Corrected value = 0
# Black-box correction at index 13699: Corrected value = 0
# Black-box correction at index 13700: Corrected value = 0
# Black-box correction at index 13701: Corrected value = 0
# Black-box correction at index 13702: Corrected value = 0.875
# Black-box correction at index 13703: Corrected value = 1.125
# Black-box correction at index 13704: Corrected value = 1.0
# Black-box correction at index 13708: Corrected value = 3.75
# Black-box correction at index 13709: Corrected value = 5.625
# Black-box correction at index 13719: Corrected value = 8.0
# Black-box correction at index 13725: Corrected value = 5.125
# Black-box correction at index 13734: Corrected value = 5.875
# Black-box correction at index 13738: Corrected value = 7.375
# Black-box correction at index 13797: Corrected value = 0
# Black-box correction at index 13798: Corrected value = 1.25
# Black-box correction at index 13799: Corrected value = 1.25
# Black-box correction at index 13800: Corrected value = 1.125
# Black-box correction at index 13801: Corrected value = 1.125
# Black-box correction at index 13837: Corrected value = 7.875
# Black-box correction at index 13952: Corrected value = 3.875
# Black-box correction at index 13954: Corrected value = 5.75
# Black-box correction at index 13972: Corrected value = 3.0
# Black-box correction at index 13974: Corrected value = 0.125
# Black-box correction at index 13975: Corrected value = 0
# Black-box correction at index 13976: Corrected value = 0
# Black-box correction at index 13977: Corrected value = 0
# Black-box correction at index 13978: Corrected value = 0
# Black-box correction at index 13979: Corrected value = 0
# Black-box correction at index 13980: Corrected value = 0
# Black-box correction at index 13981: Corrected value = 0
# Black-box correction at index 13982: Corrected value = 0
# Black-box correction at index 13983: Corrected value = 0
# Black-box correction at index 13984: Corrected value = 0
# Black-box correction at index 13985: Corrected value = 0.25
# Black-box correction at index 13986: Corrected value = 0.75
# Potential installation issue detected starting at index 13974
# Black-box correction at index 13988: Corrected value = 1.0
# Black-box correction at index 13993: Corrected value = 2.0
# Black-box correction at index 13995: Corrected value = 0.25
# Black-box correction at index 13999: Corrected value = 1.875
# Black-box correction at index 14039: Corrected value = 6.75
# Black-box correction at index 14055: Corrected value = 7.0
# Black-box correction at index 14056: Corrected value = 6.875
# Black-box correction at index 14064: Corrected value = 6.375
# Black-box correction at index 14069: Corrected value = 4.5
# Black-box correction at index 14070: Corrected value = 4.375
# Black-box correction at index 14071: Corrected value = 2.25
# Black-box correction at index 14074: Corrected value = 0.0
# Black-box correction at index 14075: Corrected value = 2.0
# Black-box correction at index 14076: Corrected value = 2.125
# Black-box correction at index 14077: Corrected value = 1.5
# Black-box correction at index 14078: Corrected value = 1.25
# Black-box correction at index 14093: Corrected value = 6.75
# Black-box correction at index 14094: Corrected value = 7.75
# Black-box correction at index 14096: Corrected value = 8.375
# Black-box correction at index 14117: Corrected value = 5.25
# Black-box correction at index 14119: Corrected value = 4.375
# Black-box correction at index 14159: Corrected value = 6.375
# Black-box correction at index 14208: Corrected value = 4.125
# Black-box correction at index 14209: Corrected value = 3.25
# Black-box correction at index 14214: Corrected value = 8.5
# Black-box correction at index 14220: Corrected value = 8.0
# Black-box correction at index 14247: Corrected value = 5.125
# Black-box correction at index 14263: Corrected value = 1.625
# Black-box correction at index 14265: Corrected value = 2.375
# Black-box correction at index 14266: Corrected value = 1.375
# Black-box correction at index 14273: Corrected value = 0.75
# Black-box correction at index 14276: Corrected value = 0.75
# Black-box correction at index 14284: Corrected value = 4.625
# Black-box correction at index 14319: Corrected value = 8.125
# Black-box correction at index 14354: Corrected value = 5.125
# Black-box correction at index 14367: Corrected value = 0.0
# Black-box correction at index 14371: Corrected value = 0
# Black-box correction at index 14375: Corrected value = 1.75
# Black-box correction at index 14376: Corrected value = 1.875
# Black-box correction at index 14394: Corrected value = 3.5
# Black-box correction at index 14428: Corrected value = 2.125
# Black-box correction at index 14432: Corrected value = 5.625
# Black-box correction at index 14540: Corrected value = 8.5
# Black-box correction at index 14584: Corrected value = 9.75
# Black-box correction at index 14606: Corrected value = 3.5
# Black-box correction at index 14614: Corrected value = 4.25
# Black-box correction at index 14683: Corrected value = 6.25
# Black-box correction at index 14692: Corrected value = 7.75
# Black-box correction at index 14723: Corrected value = 4.125
# Black-box correction at index 14733: Corrected value = 5.5
# Black-box correction at index 14769: Corrected value = 9.75
# Black-box correction at index 14774: Corrected value = 9.125
# Black-box correction at index 14798: Corrected value = 10.375
# Black-box correction at index 14838: Corrected value = 5.25
# Black-box correction at index 14905: Corrected value = 11.625
# Black-box correction at index 14906: Corrected value = 9.5
# Black-box correction at index 14927: Corrected value = 6.875
# Black-box correction at index 14966: Corrected value = 4.625
# Black-box correction at index 15103: Corrected value = 7.5
# Black-box correction at index 15122: Corrected value = 7.625
# Black-box correction at index 15190: Corrected value = 9.375
# Black-box correction at index 15197: Corrected value = 7.375
# Black-box correction at index 15383: Corrected value = 11.25
# Black-box correction at index 15445: Corrected value = 10.25
# Black-box correction at index 15505: Corrected value = 8.75
# Black-box correction at index 15508: Corrected value = 0.375
# Black-box correction at index 15510: Corrected value = 2.25
# Black-box correction at index 15511: Corrected value = 2.25
# Black-box correction at index 15512: Corrected value = 1.125
# Black-box correction at index 15514: Corrected value = 3.0
# Black-box correction at index 15517: Corrected value = 5.875
# Black-box correction at index 15585: Corrected value = 4.75
# Black-box correction at index 15589: Corrected value = 4.375
# Black-box correction at index 15633: Corrected value = 8.625
# Black-box correction at index 15680: Corrected value = 9.375
# Black-box correction at index 15731: Corrected value = 8.0
# Black-box correction at index 15861: Corrected value = 7.5
# Black-box correction at index 15866: Corrected value = 6.625
# Black-box correction at index 15928: Corrected value = 6.875
# Black-box correction at index 15932: Corrected value = 5.0
# Black-box correction at index 15980: Corrected value = 8.625
# Black-box correction at index 15981: Corrected value = 8.375
# Black-box correction at index 16070: Corrected value = 6.75
# Black-box correction at index 16112: Corrected value = 8.125
# Black-box correction at index 16127: Corrected value = 7.0
# Black-box correction at index 16148: Corrected value = 6.25
# Black-box correction at index 16174: Corrected value = 6.625
# Black-box correction at index 16373: Corrected value = 5.5
# Black-box correction at index 16375: Corrected value = 4.125
# Black-box correction at index 16403: Corrected value = 5.875
# Black-box correction at index 16416: Corrected value = 8.375
# Black-box correction at index 16589: Corrected value = 2.75
# Black-box correction at index 16680: Corrected value = 2.25
# Black-box correction at index 16729: Corrected value = 7.375
# Black-box correction at index 16777: Corrected value = 2.125
# Black-box correction at index 16782: Corrected value = 4.375
# Black-box correction at index 16964: Corrected value = 2.125
# Black-box correction at index 17090: Corrected value = 5.875
# Black-box correction at index 17309: Corrected value = 6.25
# Black-box correction at index 17312: Corrected value = 4.25
# Black-box correction at index 17330: Corrected value = 5.875
# Black-box correction at index 17393: Corrected value = 2.125
# Black-box correction at index 17394: Corrected value = 2.875
# Black-box correction at index 17396: Corrected value = 5.25
# Black-box correction at index 17397: Corrected value = 3.875
# Black-box correction at index 17405: Corrected value = 4.125
# Black-box correction at index 17406: Corrected value = 3.875
# Black-box correction at index 17407: Corrected value = 4.625
# Black-box correction at index 17410: Corrected value = 4.0
# Black-box correction at index 17412: Corrected value = 4.125
# Black-box correction at index 17415: Corrected value = 5.5
# Black-box correction at index 17416: Corrected value = 6.0
# Black-box correction at index 17426: Corrected value = 5.0
# Black-box correction at index 17427: Corrected value = 4.25
# Black-box correction at index 17428: Corrected value = 2.875
# Black-box correction at index 17457: Corrected value = 6.375
# Black-box correction at index 17522: Corrected value = 1.75
# Black-box correction at index 17523: Corrected value = 0.75
# Black-box correction at index 17524: Corrected value = 0
# Black-box correction at index 17525: Corrected value = 0
# Black-box correction at index 17526: Corrected value = 0
# Black-box correction at index 17529: Corrected value = 1.0
# Black-box correction at index 17531: Corrected value = 2.75
# Black-box correction at index 17678: Corrected value = 1.125
# Black-box correction at index 17679: Corrected value = 1.5
# Black-box correction at index 17768: Corrected value = 8.125
# Black-box correction at index 17782: Corrected value = 6.25
# Black-box correction at index 17783: Corrected value = 5.75
# Black-box correction at index 17844: Corrected value = 7.5
# Black-box correction at index 17852: Corrected value = 4.875
# Black-box correction at index 17861: Corrected value = 3.625
# Black-box correction at index 17863: Corrected value = 2.375
# Black-box correction at index 17869: Corrected value = 1.5
# Black-box correction at index 17874: Corrected value = 4.0
# Black-box correction at index 17882: Corrected value = 4.625
# Black-box correction at index 17887: Corrected value = 2.375
# Black-box correction at index 17888: Corrected value = 2.0
# Black-box correction at index 17891: Corrected value = 0.75
# Black-box correction at index 17899: Corrected value = 0.0
# Black-box correction at index 17901: Corrected value = 0.5
# Black-box correction at index 17902: Corrected value = 0.25
# Black-box correction at index 17903: Corrected value = 0.25
# Black-box correction at index 17906: Corrected value = 2.875
# Black-box correction at index 17941: Corrected value = 3.75
# Black-box correction at index 17942: Corrected value = 4.375
# Black-box correction at index 17958: Corrected value = 4.5
# Black-box correction at index 18286: Corrected value = 2.5
# Black-box correction at index 18294: Corrected value = 2.125
# Black-box correction at index 18297: Corrected value = 0
# Black-box correction at index 18298: Corrected value = 0
# Black-box correction at index 18302: Corrected value = 0
# Black-box correction at index 18303: Corrected value = 0
# Black-box correction at index 18305: Corrected value = 2.375
# Black-box correction at index 18380: Corrected value = 6.0
# Black-box correction at index 18381: Corrected value = 6.5
# Black-box correction at index 18386: Corrected value = 8.625
# Black-box correction at index 18415: Corrected value = 5.875
# ...
# Black-box correction at index 20228: Corrected value = 0
# Black-box correction at index 20229: Corrected value = 0
# Black-box correction at index 20230: Corrected value = 0
# Black-box correction at index 20231: Corrected value = 0
# Black-box correction at index 20235: Corrected value = 0.25
# Black-box correction at index 20236: Corrected value = 0.75
# Black-box correction at index 20237: Corrected value = 1.625
# Black-box correction at index 20238: Corrected value = 2.25
# Black-box correction at index 20243: Corrected value = 5.375
# Black-box correction at index 20244: Corrected value = 5.0
# Black-box correction at index 20251: Corrected value = 2.625
# Black-box correction at index 20252: Corrected value = 2.625
# Black-box correction at index 20258: Corrected value = 7.375
# Black-box correction at index 20262: Corrected value = 3.375
# Black-box correction at index 20263: Corrected value = 5.375
# Black-box correction at index 20266: Corrected value = 2.0
# Black-box correction at index 20268: Corrected value = 2.875
# Black-box correction at index 20270: Corrected value = 4.0
# Black-box correction at index 20272: Corrected value = 2.75
# Black-box correction at index 20275: Corrected value = 2.125
# Black-box correction at index 20277: Corrected value = 2.875
# Black-box correction at index 20279: Corrected value = 1.375
# Black-box correction at index 20283: Corrected value = 2.25
# Black-box correction at index 20287: Corrected value = 0
# Black-box correction at index 20288: Corrected value = 0.0
# Black-box correction at index 20289: Corrected value = 0.0
# Black-box correction at index 20290: Corrected value = 0
# Black-box correction at index 20292: Corrected value = 2.5
# Black-box correction at index 20294: Corrected value = 6.875
# Black-box correction at index 20301: Corrected value = 4.0
# Black-box correction at index 20302: Corrected value = 2.875
# Black-box correction at index 20303: Corrected value = 0.25
# Black-box correction at index 20311: Corrected value = 1.125
# Black-box correction at index 20312: Corrected value = 1.125
# Black-box correction at index 20313: Corrected value = 0.125
# Black-box correction at index 20314: Corrected value = 0.25
# Black-box correction at index 20315: Corrected value = 0
# Black-box correction at index 20316: Corrected value = 0
# Black-box correction at index 20319: Corrected value = 0.375
# Black-box correction at index 20320: Corrected value = 0.0
# Black-box correction at index 20322: Corrected value = 0
# Black-box correction at index 20323: Corrected value = 0
# Black-box correction at index 20324: Corrected value = 0
# Black-box correction at index 20325: Corrected value = 0.5
# Black-box correction at index 20328: Corrected value = 0.25
# Black-box correction at index 20331: Corrected value = 0.0
# Black-box correction at index 20332: Corrected value = 1.0
# Black-box correction at index 20333: Corrected value = 3.375
# Black-box correction at index 20334: Corrected value = 2.5
# Black-box correction at index 20350: Corrected value = 2.75
# Black-box correction at index 20352: Corrected value = 3.25
# Black-box correction at index 20353: Corrected value = 0.625
# Black-box correction at index 20354: Corrected value = 1.375
# Black-box correction at index 20357: Corrected value = 5.5
# Black-box correction at index 20361: Corrected value = 7.25
# Black-box correction at index 20362: Corrected value = 6.875
# Black-box correction at index 20366: Corrected value = 3.0
# Black-box correction at index 20367: Corrected value = 3.25
# Black-box correction at index 20369: Corrected value = 1.75
# Black-box correction at index 20371: Corrected value = 5.25
# Black-box correction at index 20378: Corrected value = 9.0
# Black-box correction at index 20382: Corrected value = 5.875
# Black-box correction at index 20392: Corrected value = 6.25
# Black-box correction at index 20435: Corrected value = 5.75
# Black-box correction at index 20437: Corrected value = 4.625
# Black-box correction at index 20441: Corrected value = 9.0
# Black-box correction at index 20471: Corrected value = 9.5
# Black-box correction at index 20486: Corrected value = 5.875
# Black-box correction at index 20487: Corrected value = 7.125
# Black-box correction at index 20526: Corrected value = 4.375
# Black-box correction at index 20531: Corrected value = 4.125
# Black-box correction at index 20536: Corrected value = 6.875
# Black-box correction at index 20540: Corrected value = 7.75
# Black-box correction at index 20563: Corrected value = 7.875
# Black-box correction at index 20566: Corrected value = 7.25
# Black-box correction at index 20574: Corrected value = 11.0
# Black-box correction at index 20582: Corrected value = 9.875
# Black-box correction at index 20583: Corrected value = 9.375
# Black-box correction at index 20590: Corrected value = 11.5
# Black-box correction at index 20626: Corrected value = 10.125
# Black-box correction at index 20640: Corrected value = 3.375
# Black-box correction at index 20644: Corrected value = 5.5
# Black-box correction at index 20655: Corrected value = 0
# Black-box correction at index 20656: Corrected value = 0
# Black-box correction at index 20657: Corrected value = 0
# Black-box correction at index 20658: Corrected value = 0
# Black-box correction at index 20659: Corrected value = 0
# Black-box correction at index 20660: Corrected value = 0
# Black-box correction at index 20661: Corrected value = 0
# Black-box correction at index 20662: Corrected value = 0
# Black-box correction at index 20663: Corrected value = 0
# Black-box correction at index 20664: Corrected value = 0
# Black-box correction at index 20665: Corrected value = 0
# Black-box correction at index 20666: Corrected value = 0
# Black-box correction at index 20667: Corrected value = 0
# Black-box correction at index 20668: Corrected value = 0
# Black-box correction at index 20669: Corrected value = 0
# Black-box correction at index 20670: Corrected value = 0
# Black-box correction at index 20671: Corrected value = 0
# Black-box correction at index 20672: Corrected value = 0
# Black-box correction at index 20673: Corrected value = 0
# Black-box correction at index 20674: Corrected value = 0
# Black-box correction at index 20675: Corrected value = 0
# Black-box correction at index 20676: Corrected value = 0
# Black-box correction at index 20677: Corrected value = 0
# Black-box correction at index 20678: Corrected value = 0
# Black-box correction at index 20679: Corrected value = 0
# Black-box correction at index 20680: Corrected value = 0
# Black-box correction at index 20681: Corrected value = 0
# Black-box correction at index 20682: Corrected value = 0
# Black-box correction at index 20683: Corrected value = 0
# Black-box correction at index 20684: Corrected value = 0
# Black-box correction at index 20685: Corrected value = 0
# Black-box correction at index 20686: Corrected value = 0
# Black-box correction at index 20687: Corrected value = 0
# Black-box correction at index 20688: Corrected value = 0
# Black-box correction at index 20689: Corrected value = 0
# Potential installation issue detected starting at index 20655
# Black-box correction at index 20691: Corrected value = 0
# Black-box correction at index 20692: Corrected value = 0
# Black-box correction at index 20693: Corrected value = 0
# Black-box correction at index 20694: Corrected value = 0
# Black-box correction at index 20695: Corrected value = 0
# Black-box correction at index 20696: Corrected value = 0
# Black-box correction at index 20697: Corrected value = 0
# Black-box correction at index 20698: Corrected value = 0
# Black-box correction at index 20699: Corrected value = 0
# Black-box correction at index 20700: Corrected value = 0
# Black-box correction at index 20701: Corrected value = 0
# Black-box correction at index 20702: Corrected value = 0
# Black-box correction at index 20704: Corrected value = 0
# Black-box correction at index 20705: Corrected value = 0
# Black-box correction at index 20706: Corrected value = 0
# Black-box correction at index 20707: Corrected value = 0
# Black-box correction at index 20708: Corrected value = 0
# Black-box correction at index 20709: Corrected value = 0
# Black-box correction at index 20710: Corrected value = 0
# Black-box correction at index 20711: Corrected value = 0
# Black-box correction at index 20712: Corrected value = 0
# Black-box correction at index 20713: Corrected value = 0
# Black-box correction at index 20714: Corrected value = 0
# Black-box correction at index 20715: Corrected value = 0
# Black-box correction at index 20716: Corrected value = 0
# Black-box correction at index 20717: Corrected value = 0
# Black-box correction at index 20718: Corrected value = 0
# Black-box correction at index 20719: Corrected value = 0
# Potential installation issue detected starting at index 20704
# Black-box correction at index 20721: Corrected value = 0
# Black-box correction at index 20722: Corrected value = 0
# Black-box correction at index 20723: Corrected value = 0
# Black-box correction at index 20724: Corrected value = 0
# Black-box correction at index 20725: Corrected value = 0
# Black-box correction at index 20726: Corrected value = 0
# Black-box correction at index 20727: Corrected value = 0
# Black-box correction at index 20729: Corrected value = 0
# Black-box correction at index 20730: Corrected value = 0
# Black-box correction at index 20731: Corrected value = 0
# Black-box correction at index 20732: Corrected value = 0
# Black-box correction at index 20733: Corrected value = 0
# Black-box correction at index 20734: Corrected value = 0
# Black-box correction at index 20735: Corrected value = 0
# Black-box correction at index 20737: Corrected value = 0
# Black-box correction at index 20738: Corrected value = 0
# Black-box correction at index 20739: Corrected value = 0
# Black-box correction at index 20740: Corrected value = 0
# Black-box correction at index 20743: Corrected value = 0
# Black-box correction at index 20744: Corrected value = 0
# Black-box correction at index 20745: Corrected value = 0
# Black-box correction at index 20746: Corrected value = 0
# Black-box correction at index 20747: Corrected value = 0
# Black-box correction at index 20748: Corrected value = 0
# Black-box correction at index 20749: Corrected value = 0
# Black-box correction at index 20751: Corrected value = 0
# Black-box correction at index 20752: Corrected value = 0
# Black-box correction at index 20753: Corrected value = 0
# Black-box correction at index 20754: Corrected value = 0
# Black-box correction at index 20755: Corrected value = 0
# Black-box correction at index 20756: Corrected value = 0
# Black-box correction at index 20757: Corrected value = 0
# Black-box correction at index 20758: Corrected value = 0
# Black-box correction at index 20759: Corrected value = 0
# Black-box correction at index 20760: Corrected value = 0
# Black-box correction at index 20761: Corrected value = 0
# Black-box correction at index 20762: Corrected value = 0
# Black-box correction at index 20763: Corrected value = 0
# Black-box correction at index 20764: Corrected value = 0
# Black-box correction at index 20765: Corrected value = 0
# Potential installation issue detected starting at index 20751
# Black-box correction at index 20767: Corrected value = 0
# Black-box correction at index 20768: Corrected value = 0
# Black-box correction at index 20771: Corrected value = 4.0
# Black-box correction at index 20778: Corrected value = 7.875
# Black-box correction at index 20856: Corrected value = 9.25
# Black-box correction at index 20875: Corrected value = 6.75
# Black-box correction at index 20918: Corrected value = 8.75
# Black-box correction at index 20922: Corrected value = 8.375
# Black-box correction at index 20942: Corrected value = 7.125
# Black-box correction at index 20969: Corrected value = 8.875
# Black-box correction at index 21032: Corrected value = 6.5
# Black-box correction at index 21043: Corrected value = 10.25
# Black-box correction at index 21054: Corrected value = 9.0
# Black-box correction at index 21095: Corrected value = 5.75
# Black-box correction at index 21097: Corrected value = 3.0
# Black-box correction at index 21101: Corrected value = 5.375
# Black-box correction at index 21154: Corrected value = 8.0
# Black-box correction at index 21161: Corrected value = 10.5
# Black-box correction at index 21171: Corrected value = 10.125
# Black-box correction at index 21192: Corrected value = 3.125
# Black-box correction at index 21193: Corrected value = 2.375
# Black-box correction at index 21196: Corrected value = 4.0
# Black-box correction at index 21197: Corrected value = 5.375
# Black-box correction at index 21198: Corrected value = 7.25
# Black-box correction at index 21213: Corrected value = 8.75
# Black-box correction at index 21223: Corrected value = 8.0
# Black-box correction at index 21237: Corrected value = 11.375
# Black-box correction at index 21257: Corrected value = 6.25
# Black-box correction at index 21276: Corrected value = 7.75
# Black-box correction at index 21277: Corrected value = 7.875
# Black-box correction at index 21306: Corrected value = 10.625
# Black-box correction at index 21430: Corrected value = 5.5
# Black-box correction at index 21440: Corrected value = 4.75
# Black-box correction at index 21452: Corrected value = 7.875
# Black-box correction at index 21458: Corrected value = 6.75
# Black-box correction at index 21459: Corrected value = 5.75
# Black-box correction at index 21466: Corrected value = 2.0
# Black-box correction at index 21468: Corrected value = 1.0
# Black-box correction at index 21469: Corrected value = 0
# Black-box correction at index 21470: Corrected value = 0
# Black-box correction at index 21471: Corrected value = 0
# Black-box correction at index 21472: Corrected value = 0
# Black-box correction at index 21473: Corrected value = 0
# Black-box correction at index 21474: Corrected value = 0
# Black-box correction at index 21475: Corrected value = 0
# Black-box correction at index 21476: Corrected value = 0
# Black-box correction at index 21479: Corrected value = 1.0
# Black-box correction at index 21480: Corrected value = 1.25
# Black-box correction at index 21481: Corrected value = 1.5
# Black-box correction at index 21484: Corrected value = 2.75
# Black-box correction at index 21485: Corrected value = 4.75
# Black-box correction at index 21487: Corrected value = 5.5
# Black-box correction at index 21532: Corrected value = 9.125
# Black-box correction at index 21538: Corrected value = 8.25
# Black-box correction at index 21541: Corrected value = 7.25
# Black-box correction at index 21551: Corrected value = 5.375
# Black-box correction at index 21558: Corrected value = 1.625
# Black-box correction at index 21559: Corrected value = 0.75
# Black-box correction at index 21560: Corrected value = 0
# Black-box correction at index 21561: Corrected value = 0
# Black-box correction at index 21562: Corrected value = 0
# Black-box correction at index 21563: Corrected value = 0
# Black-box correction at index 21564: Corrected value = 0
# Black-box correction at index 21565: Corrected value = 0.875
# Black-box correction at index 21566: Corrected value = 1.25
# Black-box correction at index 21567: Corrected value = 1.625
# Black-box correction at index 21575: Corrected value = 0
# Black-box correction at index 21576: Corrected value = 0.875
# Black-box correction at index 21577: Corrected value = 1.125
# Black-box correction at index 21579: Corrected value = 3.0
# Black-box correction at index 21582: Corrected value = 4.625
# Black-box correction at index 21583: Corrected value = 4.75
# Black-box correction at index 21633: Corrected value = 8.125
# Black-box correction at index 21637: Corrected value = 6.875
# Black-box correction at index 21752: Corrected value = 1.875
# Black-box correction at index 21753: Corrected value = 0.75
# Black-box correction at index 21755: Corrected value = 0
# Black-box correction at index 21757: Corrected value = 0.625
# Black-box correction at index 21762: Corrected value = 1.5
# Black-box correction at index 21764: Corrected value = 1.375
# Black-box correction at index 21765: Corrected value = 1.125
# Black-box correction at index 21768: Corrected value = 3.375
# Black-box correction at index 21776: Corrected value = 8.125
# Black-box correction at index 21790: Corrected value = 7.75

# %%
# Step 2: Check for spikes bigger than 200 mm relative to the previous data
def check_spikes(main_data):
    """
    This function checks for spikes that are more than 200 mm larger than the previous data
    and corrects them if found. If more than 4 consecutive spikes are on the same level,
    they are not averaged. The correction is done by averaging the previous 2-4 values 
    and forward 2-4 values.
    """
    spike_threshold = 130
    corrected_data = main_data.copy()
    consecutive_spikes = 0  # To track consecutive spikes

    for i in range(1, len(main_data) - 1):
        level_value = main_data.loc[i, 'Level']
        previous_value = main_data.loc[i-1, 'Level']
        
        # Check if the spike is more than 200 mm larger than the previous data
        if level_value > previous_value + spike_threshold:
            consecutive_spikes += 1
            
            # Check if it's a single spike (not part of a sequence longer than 4)
            if consecutive_spikes <= 4:
                # Get the previous 2-4 readings (within bounds)
                previous_readings = main_data['Level'].iloc[max(0, i-4):i].values
                # Get the forward 2-4 readings (within bounds)
                forward_readings = main_data['Level'].iloc[i+1:min(len(main_data), i+5)].values
                
                # Combine previous and forward readings to compute average
                all_readings = np.concatenate((previous_readings, forward_readings))
                if len(all_readings) > 0:
                    corrected_value = np.mean(all_readings)
                else:
                    corrected_value = level_value  # If no readings are available, leave the spike as it is
                
                # Apply the correction
                corrected_data.loc[i, 'Level'] = corrected_value
                print(f"Spike detected at index {i} with value {level_value}. Corrected to: {corrected_value}")
        
        else:
            # If no spike is detected, reset consecutive spikes
            if consecutive_spikes > 4:
                print(f"More than 4 consecutive spikes detected starting at index {i - consecutive_spikes}. No correction applied.")
            
            consecutive_spikes = 0  # Reset the consecutive spike count when no spike is detected
    
    return corrected_data

# Apply the spike checking and correction
corrected_data = check_spikes(corrected_data)

# Save the cleaned and corrected data back to a CSV file
corrected_data.to_csv('corrected_level_data.csv', index=False)
# Out:
# Spike detected at index 1 with value 250.0. Corrected to: 0.0
# Spike detected at index 15393 with value 150.0. Corrected to: 78.75

# %%
import matplotlib.pyplot as plt

# Create a figure with subplots
plt.figure(figsize=(18, 12))

# Plot 1: Comparison of original and corrected data
plt.subplot(3, 1, 1)
plt.plot(main_data['time'], main_data['Level'], label='Original Data', color='blue', alpha=0.6)
plt.plot(corrected_data['time'], corrected_data['Level'], label='Black-box Corrected Data', color='green', alpha=0.7)
plt.title('Comparison of Original vs Black-Box Corrected Level Data')
plt.xlabel('Time')
plt.ylabel('Level (mm)')
plt.legend()
plt.grid(True)

# Plot 2: Original data only
plt.subplot(3, 1, 2)
plt.plot(main_data['time'], main_data['Level'], label='Original Data', color='blue')
plt.title('Original Level Data')
plt.xlabel('Time')
plt.ylabel('Level (mm)')
plt.legend()
plt.grid(True)

# Plot 3: Black-box corrected data only
plt.subplot(3, 1, 3)
plt.plot(corrected_data['time'], corrected_data['Level'], label='Black-box Corrected Data', color='green')
plt.title('Black-Box Corrected Level Data')
plt.xlabel('Time')
plt.ylabel('Level (mm)')
plt.legend()
plt.grid(True)

# Adjust layout to prevent overlapping of subplots
plt.tight_layout()

# Show the plots
plt.show()
